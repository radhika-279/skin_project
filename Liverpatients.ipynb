# %% [markdown]
# ## Liverpatient Pred ##
# Patients with Liver disease have been continuously increasing because of excessive consumption of alcohol, inhale of harmful gases, intake of contaminated food, pickles and drugs. This dataset was used to evaluate prediction algorithms in an effort to reduce burden on doctors.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Indian Liver Patient Dataset.csv')
df
# Out:
#      65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0    62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1    62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2    58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3    72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4    46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1
# ..   ..    ...   ...  ...  ...  ..  ...  ...  ...   ... ..
# 577  60   Male   0.5  0.1  500  20   34  5.9  1.6  0.37  2
# 578  40   Male   0.6  0.1   98  35   31  6.0  3.2  1.10  1
# 579  52   Male   0.8  0.2  245  48   49  6.4  3.2  1.00  1
# 580  31   Male   1.3  0.5  184  29   32  6.8  3.4  1.00  1
# 581  38   Male   1.0  0.3  216  21   24  7.3  4.4  1.50  2
#
# [582 rows x 11 columns]

# %% [markdown]
# Here col-name is not defined so manualy add that

# %%
column_names = [
    'Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase', 'Total_Protiens',
    'Albumin', 'Albumin_and_Globulin_Ratio', 'class']

df.columns=column_names

# %%
df
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62   Male             10.9               5.5                   699
# 1     62   Male              7.3               4.1                   490
# 2     58   Male              1.0               0.4                   182
# 3     72   Male              3.9               2.0                   195
# 4     46   Male              1.8               0.7                   208
# ..   ...    ...              ...               ...                   ...
# 577   60   Male              0.5               0.1                   500
# 578   40   Male              0.6               0.1                    98
# 579   52   Male              0.8               0.2                   245
# 580   31   Male              1.3               0.5                   184
# 581   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
df.value_counts('class')
# Out:
# class
# 1    415
# 2    167
# Name: count, dtype: int64

# %% [markdown]
# This data set contains 415 liver patient records and 167 non liver patient records collected from North East of Andhra Pradesh, India. The "Target" column is a class label used to divide groups into liver patients (liver disease) or not (no disease). This data set contains 441 male patient records and 142 female patient records.
#
# Here Target is Class, 1 : patient with  liver disease and 2: patient with no liver disease disease

# %% [markdown]
# ## Explanation of attribute ##
# Age: The age of the patient.
#
# Gender: The gender of the patient, which can be either male or female.
#
# Total Bilirubin: The total bilirubin level in the blood. Bilirubin is a substance produced during the normal breakdown of red blood cells and is processed by the liver.
#
# Direct Bilirubin: The direct (conjugated) bilirubin level in the blood, representing the bilirubin that is processed by the liver and ready to be excreted from the body.
#
# Alkaline Phosphotase: An enzyme related to the bile ducts; often increased when they are blocked.
#
# Alamine Aminotransferase (ALT): An enzyme found mainly in the liver. High levels can indicate liver damage.
#
# Aspartate Aminotransferase (AST): An enzyme found in several parts of the body, including the liver and muscles. Elevated levels can indicate liver damage or disease.
#
# Total Proteins: The total amount of protein in the blood, which can give insights into the overall health of the liver.
#
# Albumin: A protein made by the liver. Low levels can indicate liver disease or other health issues.
#
# Albumin and Globulin Ratio: The ratio of albumin to globulin, which can be used to assess liver function. A low ratio can indicate liver disease.
#
# Class: This is the class label used to indicate whether a patient has liver disease (1) or not (2).

# %% [markdown]
# # Basic checks

# %%
df.shape
# Out:
# (582, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         582 non-null    int64
#  1   Gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphotase        582 non-null    int64
#  5   Alamine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  578 non-null    float64
#  10  class                       582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  582.000000       582.000000        582.000000            582.000000
# mean    44.711340         3.303265          1.488488            290.754296
# std     16.181921         6.213926          2.810324            243.108929
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.250000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     57.750000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                582.000000                  582.000000      582.000000
# mean                  80.824742                  110.068729        6.482646
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# class                         0
# dtype: int64

# %% [markdown]
# 1. Missing Values:
# The column Albumin_and_Globulin_Ratio has 4 missing values, which may need to be handled before proceeding with analysis or modeling.
#
# 2.Data Distribution:
# - The Age column ranges from 4 to 90 years, with a mean age of about 44.7.
# - The Total_Bilirubin column has a wide range (0.4 to 75), indicating significant variation in the data.
# - Other columns, like Alkaline_Phosphotase, Alamine_Aminotransferase, and Aspartate_Aminotransferase, show high standard deviations, suggesting a broad   spread of values that could reflect varying liver conditions.
# - The target variable class appears to have two distinct values (1 and 2), which likely represent classes of liver disease (healthy vs. diseased).

# %% [markdown]
# # EDA #

# %%
# Univariate # Visualizing the distribution of numerical features
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Univariate # Visualizing the distribution of numerical features
# ----> 2 for column in df.select_dtypes(include=['float64', 'int64']).columns:
#       3     sns.histplot(df[column], kde=True)
#       4     plt.title(f'Distribution of {column}')
#
# NameError: name 'df' is not defined

# %% [markdown]
# *Normal distributions:
# Age,Total Proteins,Albumin,Albumin and Globulin Ratio. others have skewness mainly rightly skewed

# %%
#Bivariate
sns.scatterplot(x='Age', y='Total_Bilirubin', hue='class', data=df)
plt.title('Age vs Total Bilirubin')
plt.show()

# %%
sns.scatterplot(x='Alkaline_Phosphotase', y='Total_Protiens', hue='class', data=df)
plt.title('Alkaline Phosphotase vs Total Proteins')
plt.show()

# %%
#Multivariate
sns.pairplot(df)

# %%
# Box plot to see the relationship between Age and class
sns.boxplot(x='class', y='Age', data=df)
plt.show()

# %% [markdown]
# # Feature eng

# %%
#missing value
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# class                         0
# dtype: int64

# %%
df.loc[df["Albumin_and_Globulin_Ratio"].isna()]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 208   45  Female              0.9               0.3                   189
# 240   51    Male              0.8               0.2                   230
# 252   35  Female              0.6               0.2                   180
# 311   27    Male              1.3               0.6                   106
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 208                        23                          33             6.6
# 240                        24                          46             6.5
# 252                        12                          15             5.2
# 311                        25                          54             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  class
# 208      3.9                         NaN      1
# 240      3.1                         NaN      1
# 252      2.7                         NaN      2
# ...

# %%
df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].median(), inplace=True)
# Out:
# C:\Users\Radhika\AppData\Local\Temp\ipykernel_11156\3123143610.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# class                         0
# dtype: int64

# %%
#check outlier
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(12,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Count',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Outliers present:
# Total_Bilirubin,Direct_Bilirubin,Alkaline_Phosphotase,Alamine_Aminotransferase,Aspartate_Aminotransferase,Albumin_and_Globulin_Ratio

# %%
outlier_columns=['Total_Bilirubin','Direct_Bilirubin','Alkaline_Phosphotase',
                 'Alamine_Aminotransferase','Aspartate_Aminotransferase','Albumin_and_Globulin_Ratio']

#handle oulier
def handle_outlies(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_bound= Q1 - 1.5 * IQR
    upper_bound= Q3 + 1.5 * IQR
    df[column]=np.where(df[column] < lower_bound,lower_bound,df[column])
    df[column]=np.where(df[column] > upper_bound,upper_bound,df[column])

for col in outlier_columns:
    handle_outlies(df,col)

print("successfull")
# Out:
# successfull

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(12,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Count',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df[df.duplicated()]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 18    40  Female              0.9              0.30                 293.0
# 25    34    Male              4.1              2.00                 289.0
# 33    38  Female              2.6              1.20                 410.0
# 54    42    Male              5.3              2.95                 272.0
# 61    58    Male              1.0              0.50                 158.0
# 105   36    Male              5.3              2.30                 145.0
# 107   36    Male              0.8              0.20                 158.0
# 137   18    Male              0.8              0.20                 282.0
# 142   30    Male              1.6              0.40                 332.0
# 157   72    Male              0.7              0.10                 196.0
# 163   39    Male              1.9              0.90                 180.0
# 173   31    Male              0.6              0.10                 175.0
# ...

# %%
# Checking for duplicates
df_duplicate = df[df.duplicated(keep = False)] # keep = False gives you all rows with duplicate entries
df_duplicate
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 17    40  Female              0.9              0.30                 293.0
# 18    40  Female              0.9              0.30                 293.0
# 24    34    Male              4.1              2.00                 289.0
# 25    34    Male              4.1              2.00                 289.0
# 32    38  Female              2.6              1.20                 410.0
# 33    38  Female              2.6              1.20                 410.0
# 53    42    Male              5.3              2.95                 272.0
# 54    42    Male              5.3              2.95                 272.0
# 60    58    Male              1.0              0.50                 158.0
# 61    58    Male              1.0              0.50                 158.0
# 104   36    Male              5.3              2.30                 145.0
# 105   36    Male              5.3              2.30                 145.0
# ...

# %%
df.loc[df["Age"]==35]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 44    35    Male              1.8              0.60               275.000
# 236   35  Female              0.9              0.30               158.000
# 237   35  Female              0.9              0.20               190.000
# 252   35  Female              0.6              0.20               180.000
# 275   35    Male              0.9              0.20               190.000
# 316   35    Male              0.7              0.20               198.000
# 341   35    Male              0.8              0.20               198.000
# 436   35    Male              1.6              0.70               157.000
# 450   35    Male              0.8              0.20               279.000
# 473   35    Male              2.0              1.10               226.000
# 491   35  Female              1.0              0.30               482.125
# 518   35    Male              5.3              2.95               108.000
#
# ...

# %%
df = df[~df.duplicated(subset = None, keep = 'first')]
# df.drop_duplicates(inplace=True)
#keep = 'first' that only the first row is taken into the final dataset and '~' sign tells pandas to keep all values except the 13 duplicate values
df.shape
# Out:
# (569, 11)

# %% [markdown]
# Now we want to convert Gender (categorical to numerical)

# %%
np.unique(df.Gender)
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.value_counts("Gender")
# Out:
# Gender
# Male      430
# Female    139
# Name: count, dtype: int64

# %%
df["Gender"]=df["Gender"].replace({'Male':0,"Female":1})
# Out:
# C:\Users\Radhika\AppData\Local\Temp\ipykernel_11156\4092611882.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Gender"]=df["Gender"].replace({'Male':0,"Female":1})
# C:\Users\Radhika\AppData\Local\Temp\ipykernel_11156\4092611882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"]=df["Gender"].replace({'Male':0,"Female":1})

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62       0              5.3              2.95               482.125
# 1     62       0              5.3              2.95               482.125
# 2     58       0              1.0              0.40               182.000
# 3     72       0              3.9              2.00               195.000
# 4     46       0              1.8              0.70               208.000
# ..   ...     ...              ...               ...                   ...
# 577   60       0              0.5              0.10               482.125
# 578   40       0              0.6              0.10                98.000
# 579   52       0              0.8              0.20               245.000
# 580   31       0              1.3              0.50               184.000
# 581   38       0              1.0              0.30               216.000
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                  Age    Gender  Total_Bilirubin  \
# Age                         1.000000 -0.062314         0.104363
# Gender                     -0.062314  1.000000        -0.176942
# Total_Bilirubin             0.104363 -0.176942         1.000000
# Direct_Bilirubin            0.099316 -0.175933         0.982651
# Alkaline_Phosphotase        0.043661 -0.051265         0.362380
# Alamine_Aminotransferase   -0.063455 -0.156958         0.445864
# Aspartate_Aminotransferase -0.025315 -0.162441         0.540192
# Total_Protiens             -0.197943  0.085271        -0.069978
# Albumin                    -0.271961  0.091034        -0.305098
# Albumin_and_Globulin_Ratio -0.224073  0.014151        -0.329511
# class                      -0.136940  0.080705        -0.321743
#
#                             Direct_Bilirubin  Alkaline_Phosphotase  \
# Age                                 0.099316              0.043661
# ...

# %%
df1=df.copy()

# %% [markdown]
# # Modelling

# %%
df.shape
# Out:
# (569, 11)

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns=["class"])
y = df['class']

y = y.replace({1: 0, 2: 1})

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 577    1
# 578    0
# 579    0
# 580    0
# 581    1
# Name: class, Length: 569, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
print(x_test.shape)
print(x_train.shape)
# Out:
# (114, 10)
# (455, 10)

# %%
#checking balanced or not 
print(y.value_counts())

y.value_counts(normalize=True)*100
# Out:
# class
# 0    405
# 1    164
# Name: count, dtype: int64
# class
# 0    71.177504
# 1    28.822496
# Name: proportion, dtype: float64

# %% [markdown]
# here data is imbalance so want to use SMOTE

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier()
xgb_model.fit(x, y)

importance = xgb_model.get_booster().get_score(importance_type='weight')# get feature importance using the 'weight' method

importance_df = pd.DataFrame(importance.items(), columns=['Feature', 'Importance']) # to convert the feature importance into a DataFrame
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print("Important features based on XGBoost's feature importance:")
print(importance_df)

top_features = importance_df['Feature'].head(10).tolist() # Select the important features (top 10)
X_selected = x[top_features] # Use selected important features for further modeling

sns.barplot(x='Importance', y='Feature', data=importance_df.head(10))
# Out:
# Important features based on XGBoost's feature importance:
#                       Feature  Importance
# 4        Alkaline_Phosphotase       264.0
# 0                         Age       237.0
# 5    Alamine_Aminotransferase       215.0
# 6  Aspartate_Aminotransferase       192.0
# 8                     Albumin       183.0
# 7              Total_Protiens       152.0
# 9  Albumin_and_Globulin_Ratio       119.0
# 2             Total_Bilirubin       102.0
# 3            Direct_Bilirubin        61.0
# 1                      Gender        30.0
# <Axes: xlabel='Importance', ylabel='Feature'>

# %%
x
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62       0              5.3              2.95               482.125
# 1     62       0              5.3              2.95               482.125
# 2     58       0              1.0              0.40               182.000
# 3     72       0              3.9              2.00               195.000
# 4     46       0              1.8              0.70               208.000
# ..   ...     ...              ...               ...                   ...
# 577   60       0              0.5              0.10               482.125
# 578   40       0              0.6              0.10                98.000
# 579   52       0              0.8              0.20               245.000
# 580   31       0              1.3              0.50               184.000
# 581   38       0              1.0              0.30               216.000
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
x.drop(columns=["Direct_Bilirubin"],inplace=True) 
#in total bilirubin and direct bilirubin has same corelation value and highly corelated(>0.9) so we want to drop one.Here droping direct bilirubin because from feature importance we get total bilirubin is more important that direct bilirubin.
# X_selected.drop(columns=["Direct_Bilirubin"], inplace=True)

# %% [markdown]
# # XGBoost Model

# %%
#split data by selected feature
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (455, 9)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x_train_res, y_train_res = smote.fit_resample(x_train, y_train)
x_train_res.shape , y_train_res.shape
# Out:
# ((638, 9), (638,))

# %% [markdown]
# # xgboost

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score,roc_curve, roc_auc_score, auc


xgb_model = xgb.XGBClassifier()
xgb_model.fit(x_train_res, y_train_res)

y_pred_xgb = xgb_model.predict(x_test)

# Evaluate the model
print("XGBoost Model Evaluation")
print(classification_report(y_test, y_pred_xgb))
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f'XGBoost Accuracy: {accuracy_xgb:.4f}')
f1_xgb = f1_score(y_test, y_pred_xgb)
print(f'XGBoost F1 score: {f1_xgb:.4f}')
# Out:
# XGBoost Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80        86
#            1       0.38      0.39      0.39        28
#
#     accuracy                           0.69       114
#    macro avg       0.59      0.59      0.59       114
# weighted avg       0.70      0.69      0.69       114
#
# XGBoost Accuracy: 0.6930
# XGBoost F1 score: 0.3860

# %%
# Cross-validation and hyperparameter tuning with Stratified K-Fold

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV

xgb_model = xgb.XGBClassifier()

# Define hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.2, 0.3],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, 
                           cv=cv, n_jobs=-1, verbose=1, scoring='f1')

grid_search.fit(x_train, y_train)

print(f"Best Hyperparameters: {grid_search.best_params_}") # Best hyperparameters from GridSearchCV

best_xgb_model = grid_search.best_estimator_  # Use the best model from grid search for evaluation

y_pred_xgb = best_xgb_model.predict(x_test)

# Evaluate the model
print("XGBoost Model Evaluation")
print(classification_report(y_test, y_pred_xgb))
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f'XGBoost Accuracy: {accuracy_xgb:.4f}')
f1_xgb = f1_score(y_test, y_pred_xgb)
print(f'XGBoost F1 score: {f1_xgb:.4f}')

cm = confusion_matrix(y_test, y_pred_xgb)
print(f'confusion metrics:',cm)

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, best_xgb_model.predict_proba(x_test)[:,1])
roc_auc = auc(fpr, tpr)
print(f"XGBoost ROC AUC: {roc_auc:.4f}")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# Best Hyperparameters: {'colsample_bytree': 1.0, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# XGBoost Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81        86
#            1       0.41      0.43      0.42        28
#
#     accuracy                           0.71       114
#    macro avg       0.61      0.62      0.61       114
# weighted avg       0.71      0.71      0.71       114
#
# XGBoost Accuracy: 0.7105
# XGBoost F1 score: 0.4211
# confusion metrics: [[69 17]
#  [16 12]]
# XGBoost ROC AUC: 0.6682

# %% [markdown]
# # Logistic Reg

# %%
from sklearn.linear_model import LogisticRegression

logreg_model = LogisticRegression(max_iter=1000)
logreg_model.fit(x_train_res, y_train_res)

y_pred_logreg = logreg_model.predict(x_test)
y_pred_proba_logreg = logreg_model.predict_proba(x_test)[:, 1]

# Evaluate the model
print("Logistic Regression Model Evaluation")
print(classification_report(y_test, y_pred_logreg))
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f'Logistic Regression Accuracy: {accuracy_logreg:.4f}')
f1_logreg = f1_score(y_test, y_pred_logreg)
print(f'Logreg F1 score: {f1_logreg:.4f}')
roc_auc_logreg = roc_auc_score(y_test, y_pred_proba_logreg)
print(f'Logistic Regression ROC AUC: {roc_auc_logreg:.4f}')

cm = confusion_matrix(y_test, y_pred_logreg)
print(f'confusion metrics:',cm)
# Out:
# Logistic Regression Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.86      0.58      0.69        86
#            1       0.36      0.71      0.48        28
#
#     accuracy                           0.61       114
#    macro avg       0.61      0.65      0.59       114
# weighted avg       0.74      0.61      0.64       114
#
# Logistic Regression Accuracy: 0.6140
# Logreg F1 score: 0.4762
# Logistic Regression ROC AUC: 0.6653
# confusion metrics: [[50 36]
#  [ 8 20]]

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train_res, y_train_res)

y_pred_rf = rf_model.predict(x_test)
y_pred_proba_rf = rf_model.predict_proba(x_test)[:, 1]

# Evaluate the model
print("Random Forest Model Evaluation")
print(classification_report(y_test, y_pred_rf))
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Random Forest Accuracy: {accuracy_rf:.4f}')
F1_rf = f1_score(y_test, y_pred_rf)
print(f'RF F1 score: {F1_rf:.4f}')
roc_auc_rf = roc_auc_score(y_test, y_pred_proba_rf)
print(f'Random Forest ROC AUC: {roc_auc_rf:.4f}')

cm = confusion_matrix(y_test, y_pred_rf)
print(f'confusion metrics:',cm)
# Out:
# Random Forest Model Evaluation
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78        86
#            1       0.38      0.46      0.42        28
#
#     accuracy                           0.68       114
#    macro avg       0.60      0.61      0.60       114
# weighted avg       0.71      0.68      0.69       114
#
# Random Forest Accuracy: 0.6842
# RF F1 score: 0.4194
# Random Forest ROC AUC: 0.6933
# confusion metrics: [[65 21]
#  [15 13]]
